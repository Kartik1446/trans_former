# %% [markdown]
# <h1><center> Micrograd</h1>

# %% [markdown]
# AUTO-GRAD -> AUTOMATIC GRADIENT
#
# Micrograd is an Autograd engine. It implements backpropagation over a dynamically built DAG and a small neural networks library on top of it with a PyTorch like API. Both are tiny with about 100 and 50 lines of code respectively. The DAG only operates over scalar values.

# %% [markdown]
# Installation:

# %%
# !pip install micrograd

# %% [markdown]
# # Micrograd — Intuition (Short)
#
# * What is it?
#
# Micrograd is a tiny library that helps you understand how **gradients (derivatives)** are computed automatically.
#
#
#
# * Smart Numbers

# %%
from micrograd.engine import Value
a= Value(-4.0)
b= Value(2.0)
c= a+b
d= a*b+ b**3
c += c+1
c+= 1+c+ (-a)
d+= d*2 + (b+a).relu()
d+= 3*d+(b-a).relu()
e= c-d
f= e**2
g= f/2.0
g+= 10.0/f
print(f'{g.data:.4f}')
g.backward()
print(f'{a.data:.4f}')
print(f'{b.data:.4f}')
# Out:
# 24.7041
# -4.0000
# 2.0000
# -1.0000

# %% [markdown]
# ## Understanding the code

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x):
    return 3*x**2 -4*x +5

# %%
f(3)
# Out:
# 20

# %%
f(3.0)
# Out:
# 20.0

# %%
xs= np.arange(-5, 5, 0.25)
xs
# Out:
# array([-5.  , -4.75, -4.5 , -4.25, -4.  , -3.75, -3.5 , -3.25, -3.  ,
#        -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  , -0.75,
#        -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,
#         1.75,  2.  ,  2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,
#         4.  ,  4.25,  4.5 ,  4.75])
